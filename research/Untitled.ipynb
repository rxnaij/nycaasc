# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/chuamelia/Desktop/nycaasc/research/data/fb/2016_spring_page_level_.csv")

# %%
data.head()
# Out:
#         ﻿Date                               Lifetime Total Likes  \
# 0         NaN  Lifetime: The total number of people who have ...
# 1  2016-01-01                                               1070
# 2  2016-01-02                                               1070
# 3  2016-01-03                                               1070
# 4  2016-01-04                                               1071
#
#                                      Daily New Likes  \
# 0  Daily: The number of new people who have liked...
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#                                        Daily Unlikes  \
# 0  Daily: The number of Unlikes of your Page (Uni...
# 1                                                  0
# 2                                                  0
# ...

# %%
(ln(1+4(10^(-1)))/4(10^(-1)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a37f794e356f> in <module>()
# ----> 1 ((4)^4)/4+(1/(8(()^2)))
#
# TypeError: unsupported operand type(s) for ^: 'tuple' and 'int'
